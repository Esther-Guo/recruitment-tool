# %% [markdown]
# # US Population Data

# %% [markdown]
# Chanin Nantasenamat, Ph.D.

# %% [markdown]
# ## Load data

# %%
import pandas as pd

df_overview = pd.read_csv('data/staff-info.csv')
df_overview
# Out:
#     Staff ID               Name  Gender                 IAEA Profession  \
# 0       1001         John Smith    Male                      Inspectors
# 1       1002      Alice Johnson  Female          Information Technology
# 2       1003  Mohammed Al-Farsi    Male          Laboratory Specialists
# 3       1004        Anna Müller  Female            Information Analysts
# 4       1005         Juan Perez    Male  Policy&Management Coordination
# 5       1006           Chen Wei    Male                      Inspectors
# 6       1007        Emily Brown  Female          Information Technology
# 7       1008         Ravi Patel    Male          Laboratory Specialists
# 8       1009       Maria Santos  Female            Information Analysts
# 9       1010     Mustafa Hassan    Male  Policy&Management Coordination
# 10      1011      Sophie Dupont  Female                      Inspectors
# 11      1012         Kim Min-ji  Female          Information Technology
# 12      1013   Alexander Ivanov    Male          Laboratory Specialists
# 13      1014             Li Wei  Female            Information Analysts
# 14      1015        Lisa Müller  Female  Policy&Management Coordination
# 15      1016      Antonio Lopez    Male                      Inspectors
# 16      1017      Emily Johnson  Female          Information Technology
# 17      1018        Rahul Singh    Male          Laboratory Specialists
# 18      1019          Ana Silva  Female            Information Analysts
# 19      1020      Ahmed Mahmoud    Male  Policy&Management Coordination
# 20      1021       Sarah Dubois  Female                      Inspectors
# 21      1022       Park Joon-ho    Male          Information Technology
# 22      1023        Ivan Petrov    Male          Laboratory Specialists
# 23      1024           Wang Lei    Male            Information Analysts
# 24      1025       Maria Garcia  Female  Policy&Management Coordination
# 25      1026       David Miller    Male                      Inspectors
# 26      1027        Lucia Costa  Female          Information Technology
# 27      1028      Sandeep Kumar    Male          Laboratory Specialists
# 28      1029    Carla Rodriguez  Female            Information Analysts
# 29      1030     Khalid Ibrahim    Male  Policy&Management Coordination
# 30      1031     Elena Dubrovna  Female                      Inspectors
# 31      1032            Liu Hui    Male          Information Technology
# 32      1033         Emma Smith  Female          Laboratory Specialists
# 33      1034         Ravi Patel    Male            Information Analysts
# 34      1035         Ana Santos  Female  Policy&Management Coordination
# 35      1036       Ahmed Hassan    Male                      Inspectors
# 36      1037      Sophie Leroux  Female          Information Technology
# 37      1038           Chen Wei    Male          Laboratory Specialists
# 38      1039       Olga Ivanova  Female            Information Analysts
# 39      1040            Li Ming    Male  Policy&Management Coordination
# 40      1041        Lucas Silva    Male                      Inspectors
# 41      1042        Jung Eun-ji  Female          Information Technology
# 42      1043      Sergei Petrov    Male          Laboratory Specialists
# 43      1044          Wang Fang    Male            Information Analysts
# 44      1045       Andrea Lopez  Female  Policy&Management Coordination
# 45      1046      Michael Brown    Male                      Inspectors
# 46      1047        Marta Costa  Female          Information Technology
# 47      1048       Rajesh Kumar    Male          Laboratory Specialists
# 48      1049  Juliana Rodriguez  Female            Information Analysts
# 49      1050       Yousef Ahmed    Male  Policy&Management Coordination
#
#        Nationality iso_alpha                Academic Pre-IAEA Work Experience  \
# 0    United States       USA        Nuclear Engineer           Nuclear Energy
# 1           Canada       CAN        Computer Science               Government
# 2     Saudi Arabia       SAU               Chemistry                 Academia
# 3          Germany       DEU     Information Science                      NGO
# 4            Spain       ESP         Int'l Relations                   Health
# 5            China       CHN         Nuclear Physics           Nuclear Energy
# 6   United Kingdom       GBR    Computer Engineering               Government
# 7            India       IND    Chemical Engineering                 Academia
# 8           Brazil       BRA         Library Science                      NGO
# 9            Egypt       EGY       Political Science               Government
# 10          France       FRA     Nuclear Engineering           Nuclear Energy
# 11     South Korea       KOR    Software Engineering                   Health
# 12          Russia       RUS            Biochemistry                 Academia
# 13           China       CHN            Data Science                      NGO
# 14         Germany       DEU           Public Policy               Government
# 15           Spain       ESP                 Physics           Nuclear Energy
# 16   United States       USA        Computer Science                   Health
# 17           India       IND           Biotechnology                 Academia
# 18          Brazil       BRA     Information Systems                      NGO
# 19           Egypt       EGY              Management               Government
# 20          France       FRA         Nuclear Physics           Nuclear Energy
# 21     South Korea       KOR  Information Technology                      NGO
# 22          Russia       RUS               Chemistry                 Academia
# 23           China       CHN    Computer Engineering                   Health
# 24           Spain       ESP               Economics               Government
# 25   United States       USA     Nuclear Engineering           Nuclear Energy
# 26        Portugal       PRT        Computer Science                      NGO
# 27           India       IND               Chemistry                   Health
# 28          Brazil       BRA         Library Science                 Academia
# 29           Egypt       EGY   Public Administration               Government
# 30          Russia       RUS         Nuclear Physics           Nuclear Energy
# 31           China       CHN    Software Engineering                      NGO
# 32  United Kingdom       GBR                 Biology                 Academia
# 33           India       IND            Data Science                   Health
# 34          Brazil       BRA           Public Policy               Government
# 35           Egypt       EGY       Political Science           Nuclear Energy
# 36          France       FRA    Computer Engineering                      NGO
# 37           China       CHN    Chemical Engineering                 Academia
# 38          Russia       RUS     Information Systems                      NGO
# 39           China       CHN              Management               Government
# 40          Brazil       BRA         Nuclear Physics           Nuclear Energy
# 41     South Korea       KOR  Information Technology                   Health
# 42          Russia       RUS            Biochemistry                      NGO
# 43           China       CHN    Computer Engineering                 Academia
# 44           Spain       ESP               Economics               Government
# 45   United States       USA     Nuclear Engineering           Nuclear Energy
# 46        Portugal       PRT        Computer Science                   Health
# 47           India       IND               Chemistry                 Academia
# 48          Brazil       BRA         Library Science                      NGO
# 49           Egypt       EGY   Public Administration               Government
#
#     Generational
# 0   Generation X
# 1    Millennials
# 2   Generation Z
# 3   Baby Boomers
# 4   Generation X
# 5   Generation Z
# 6    Millennials
# 7   Generation Y
# 8   Baby Boomers
# 9   Generation X
# 10   Millennials
# 11  Generation Z
# 12  Generation X
# 13  Generation Y
# 14  Baby Boomers
# 15  Generation X
# 16  Generation Z
# 17  Generation Y
# 18  Generation X
# 19   Millennials
# 20  Baby Boomers
# 21  Generation Z
# 22  Generation Y
# 23  Generation X
# 24  Generation Z
# 25  Generation Y
# 26  Generation X
# 27   Millennials
# 28  Generation Z
# 29  Generation Y
# 30  Generation X
# 31  Generation Z
# 32  Generation Y
# 33  Generation X
# 34  Generation Z
# 35  Generation Y
# 36  Generation X
# 37   Millennials
# 38  Generation Z
# 39  Generation Y
# 40  Generation X
# 41   Millennials
# 42  Generation Z
# 43  Generation Y
# 44  Generation X
# 45   Millennials
# 46  Generation Z
# 47  Generation Y
# 48  Generation X
# 49  Generation Z

# %%
filtered_data = df_overview[(df_overview['Nationality'] == "China")].reset_index(drop=True)

filtered_data
# Out:
#    Staff ID       Name  Gender                 IAEA Profession Nationality  \
# 0      1006   Chen Wei    Male                      Inspectors       China
# 1      1014     Li Wei  Female            Information Analysts       China
# 2      1024   Wang Lei    Male            Information Analysts       China
# 3      1032    Liu Hui    Male          Information Technology       China
# 4      1038   Chen Wei    Male          Laboratory Specialists       China
# 5      1040    Li Ming    Male  Policy&Management Coordination       China
# 6      1044  Wang Fang    Male            Information Analysts       China
#
#   iso_alpha              Academic Pre-IAEA Work Experience  Generational
# 0       CHN       Nuclear Physics           Nuclear Energy  Generation Z
# 1       CHN          Data Science                      NGO  Generation Y
# 2       CHN  Computer Engineering                   Health  Generation X
# 3       CHN  Software Engineering                      NGO  Generation Z
# 4       CHN  Chemical Engineering                 Academia   Millennials
# 5       CHN            Management               Government  Generation Y
# 6       CHN  Computer Engineering                 Academia  Generation Y

# %%
for idx, name in enumerate(filtered_data["Name"]):
    print(idx)
    print(name)
# Out:
# 0
# Chen Wei
# 1
# Li Wei
# 2
# Wang Lei
# 3
# Liu Hui
# 4
# Chen Wei
# 5
# Li Ming
# 6
# Wang Fang

# %%
nationality_distribution.columns = ['iso_alpha', 'count']

# %%
nationality_distribution
# Out:
#          iso_alpha  count
# 0            China      7
# 1           Brazil      6
# 2            India      5
# 3            Egypt      5
# 4           Russia      5
# 5    United States      4
# 6            Spain      4
# 7           France      3
# 8      South Korea      3
# 9          Germany      2
# 10  United Kingdom      2
# 11        Portugal      2
# 12          Canada      1
# 13    Saudi Arabia      1

# %%
diversity_distribution = df_overview['Generational'].value_counts()

# %%
diversity_distribution
# Out:
# Generational
# Generation X    14
# Generation Z    13
# Generation Y    11
# Millennials      8
# Baby Boomers     4
# Name: count, dtype: int64

# %%
diversity_distribution
# Out:
# Generational
# Generation X    14
# Generation Z    13
# Generation Y    11
# Millennials      8
# Baby Boomers     4
# Name: count, dtype: int64

# %%
gender_distribution = df_overview['Gender'].value_counts()

# %%
gender_distribution.Male
# Out:
# 28

# %%
import streamlit as st
colms = st.columns((1, 2, 2, 1, 1))
fields = ["№", 'email', 'uid', 'verified', "action"]
for col, field_name in zip(colms, fields):
    # header
    col.write(field_name)
# Out:
# 2024-03-14 09:02:54.920
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/vscode/.local/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]

# %% [markdown]
# ## Data pre-processing

# %%
# Reshape the DataFrame
df_reshaped = pd.melt(df, id_vars=['states', 'states_code', 'id'], var_name='year', value_name='population')

# Convert 'year' column values to integers
df_reshaped['states'] = df_reshaped['states'].astype(str)
df_reshaped['year'] = df_reshaped['year'].astype(int)
df_reshaped['population'] = df_reshaped['population'].str.replace(',', '').astype(int)

df_reshaped
# Out:
#             states states_code  id  year  population
# 0          Alabama          AL   1  2010     4785437
# 1           Alaska          AK   2  2010      713910
# 2          Arizona          AZ   4  2010     6407172
# 3         Arkansas          AR   5  2010     2921964
# 4       California          CA   6  2010    37319502
# ..             ...         ...  ..   ...         ...
# 515     Washington          WA  53  2019     7614893
# 516  West Virginia          WV  54  2019     1792147
# 517      Wisconsin          WI  55  2019     5822434
# 518        Wyoming          WY  56  2019      578759
# 519    Puerto Rico          PR  72  2019     3193694
#
# [520 rows x 5 columns]

# %%
# Save reshaped data to CSV
df_reshaped.to_csv('us-population-2010-2019-reshaped.csv')

# %%
# Subset dataframe by year
selected_year = 2019
df_selected_year = df_reshaped[df_reshaped.year == selected_year]
df_selected_year
# Out:
#                    states states_code  id  year  population
# 468               Alabama          AL   1  2019     4903185
# 469                Alaska          AK   2  2019      731545
# 470               Arizona          AZ   4  2019     7278717
# 471              Arkansas          AR   5  2019     3017804
# 472            California          CA   6  2019    39512223
# 473              Colorado          CO   8  2019     5758736
# 474           Connecticut          CT   9  2019     3565287
# 475              Delaware          DE  10  2019      973764
# 476  District of Columbia          DC  11  2019      705749
# 477               Florida          FL  12  2019    21477737
# 478               Georgia          GA  13  2019    10617423
# 479                Hawaii          HI  15  2019     1415872
# 480                 Idaho          ID  16  2019     1787065
# 481              Illinois          IL  17  2019    12671821
# 482               Indiana          IN  18  2019     6732219
# 483                  Iowa          IA  19  2019     3155070
# 484                Kansas          KS  20  2019     2913314
# 485              Kentucky          KY  21  2019     4467673
# 486             Louisiana          LA  22  2019     4648794
# 487                 Maine          ME  23  2019     1344212
# 488              Maryland          MD  24  2019     6045680
# 489         Massachusetts          MA  25  2019     6892503
# 490              Michigan          MI  26  2019     9986857
# 491             Minnesota          MN  27  2019     5639632
# 492           Mississippi          MS  28  2019     2976149
# 493              Missouri          MO  29  2019     6137428
# 494               Montana          MT  30  2019     1068778
# 495              Nebraska          NE  31  2019     1934408
# 496                Nevada          NV  32  2019     3080156
# 497         New Hampshire          NH  33  2019     1359711
# 498            New Jersey          NJ  34  2019     8882190
# 499            New Mexico          NM  35  2019     2096829
# 500              New York          NY  36  2019    19453561
# 501        North Carolina          NC  37  2019    10488084
# 502          North Dakota          ND  38  2019      762062
# 503                  Ohio          OH  39  2019    11689100
# 504              Oklahoma          OK  40  2019     3956971
# 505                Oregon          OR  41  2019     4217737
# 506          Pennsylvania          PA  42  2019    12801989
# 507          Rhode Island          RI  44  2019     1059361
# 508        South Carolina          SC  45  2019     5148714
# 509          South Dakota          SD  46  2019      884659
# 510             Tennessee          TN  47  2019     6829174
# 511                 Texas          TX  48  2019    28995881
# 512                  Utah          UT  49  2019     3205958
# 513               Vermont          VT  50  2019      623989
# 514              Virginia          VA  51  2019     8535519
# 515            Washington          WA  53  2019     7614893
# 516         West Virginia          WV  54  2019     1792147
# 517             Wisconsin          WI  55  2019     5822434
# 518               Wyoming          WY  56  2019      578759
# 519           Puerto Rico          PR  72  2019     3193694

# %%
# Sort by year
df_selected_year_sorted = df_selected_year.sort_values(by="population", ascending=False)
df_selected_year_sorted
# Out:
#                    states states_code  id  year  population
# 472            California          CA   6  2019    39512223
# 511                 Texas          TX  48  2019    28995881
# 477               Florida          FL  12  2019    21477737
# 500              New York          NY  36  2019    19453561
# 506          Pennsylvania          PA  42  2019    12801989
# 481              Illinois          IL  17  2019    12671821
# 503                  Ohio          OH  39  2019    11689100
# 478               Georgia          GA  13  2019    10617423
# 501        North Carolina          NC  37  2019    10488084
# 490              Michigan          MI  26  2019     9986857
# 498            New Jersey          NJ  34  2019     8882190
# 514              Virginia          VA  51  2019     8535519
# 515            Washington          WA  53  2019     7614893
# 470               Arizona          AZ   4  2019     7278717
# 489         Massachusetts          MA  25  2019     6892503
# 510             Tennessee          TN  47  2019     6829174
# 482               Indiana          IN  18  2019     6732219
# 493              Missouri          MO  29  2019     6137428
# 488              Maryland          MD  24  2019     6045680
# 517             Wisconsin          WI  55  2019     5822434
# 473              Colorado          CO   8  2019     5758736
# 491             Minnesota          MN  27  2019     5639632
# 508        South Carolina          SC  45  2019     5148714
# 468               Alabama          AL   1  2019     4903185
# 486             Louisiana          LA  22  2019     4648794
# 485              Kentucky          KY  21  2019     4467673
# 505                Oregon          OR  41  2019     4217737
# 504              Oklahoma          OK  40  2019     3956971
# 474           Connecticut          CT   9  2019     3565287
# 512                  Utah          UT  49  2019     3205958
# 519           Puerto Rico          PR  72  2019     3193694
# 483                  Iowa          IA  19  2019     3155070
# 496                Nevada          NV  32  2019     3080156
# 471              Arkansas          AR   5  2019     3017804
# 492           Mississippi          MS  28  2019     2976149
# 484                Kansas          KS  20  2019     2913314
# 499            New Mexico          NM  35  2019     2096829
# 495              Nebraska          NE  31  2019     1934408
# 516         West Virginia          WV  54  2019     1792147
# 480                 Idaho          ID  16  2019     1787065
# 479                Hawaii          HI  15  2019     1415872
# 497         New Hampshire          NH  33  2019     1359711
# 487                 Maine          ME  23  2019     1344212
# 494               Montana          MT  30  2019     1068778
# 507          Rhode Island          RI  44  2019     1059361
# 475              Delaware          DE  10  2019      973764
# 509          South Dakota          SD  46  2019      884659
# 502          North Dakota          ND  38  2019      762062
# 469                Alaska          AK   2  2019      731545
# 476  District of Columbia          DC  11  2019      705749
# 513               Vermont          VT  50  2019      623989
# 518               Wyoming          WY  56  2019      578759

# %%
# Calculate population difference between selected and previous year
def calculate_population_difference(input_df, input_year):
  selected_year_data = input_df[input_df['year'] == input_year].reset_index()
  previous_year_data = input_df[input_df['year'] == input_year - 1].reset_index()
  selected_year_data['population_difference'] = selected_year_data.population.sub(previous_year_data.population, fill_value=0)
  selected_year_data['population_difference_absolute'] = abs(selected_year_data['population_difference'])
  return pd.concat([selected_year_data.states, selected_year_data.id, selected_year_data.population, selected_year_data.population_difference, selected_year_data.population_difference_absolute], axis=1).sort_values(by="population_difference", ascending=False)

df_population_difference_sorted = calculate_population_difference(df_reshaped, selected_year)
df_population_difference_sorted
# Out:
#                   states  id  population  population_difference  \
# 43                 Texas  48    28995881                 367215
# 9                Florida  12    21477737                 233420
# 2                Arizona   4     7278717                 120693
# 33        North Carolina  37    10488084                 106469
# 10               Georgia  13    10617423                 106292
# 47            Washington  53     7614893                  91024
# 5               Colorado   8     5758736                  67449
# 40        South Carolina  45     5148714                  64558
# 42             Tennessee  47     6829174                  57543
# 28                Nevada  32     3080156                  52815
# 44                  Utah  49     3205958                  52408
# 4             California   6    39512223                  50635
# 14               Indiana  18     6732219                  36722
# 12                 Idaho  16     1787065                  36529
# 37                Oregon  41     4217737                  35851
# 46              Virginia  51     8535519                  34233
# 23             Minnesota  27     5639632                  33383
# 36              Oklahoma  40     3956971                  16736
# 25              Missouri  29     6137428                  15805
# 0                Alabama   1     4903185                  15504
# 49             Wisconsin  55     5822434                  15028
# 35                  Ohio  39    11689100                  12759
# 20              Maryland  24     6045680                   9878
# 21         Massachusetts  25     6892503                   9868
# 27              Nebraska  31     1934408                   8794
# 7               Delaware  10      973764                   8285
# 26               Montana  30     1068778                   8113
# 3               Arkansas   5     3017804                   8071
# 17              Kentucky  21     4467673                   6520
# 15                  Iowa  19     3155070                   6452
# 29         New Hampshire  33     1359711                   6246
# 41          South Dakota  46      884659                   5961
# 19                 Maine  23     1344212                   5155
# 8   District of Columbia  11      705749                   4202
# 31            New Mexico  35     2096829                   4088
# 34          North Dakota  38      762062                   3982
# 22              Michigan  26     9986857                   2785
# 16                Kansas  20     2913314                   1955
# 50               Wyoming  56      578759                   1158
# 39          Rhode Island  44     1059361                   1074
# 38          Pennsylvania  42    12801989                   1067
# 51           Puerto Rico  72     3193694                    340
# 45               Vermont  50      623989                   -369
# 1                 Alaska   2      731545                  -3594
# 30            New Jersey  34     8882190                  -3835
# 11                Hawaii  15     1415872                  -4721
# 24           Mississippi  28     2976149                  -4871
# 6            Connecticut   9     3565287                  -6233
# 18             Louisiana  22     4648794                 -10896
# 48         West Virginia  54     1792147                 -12144
# 13              Illinois  17    12671821                 -51250
# 32              New York  36    19453561                 -76790
#
#     population_difference_absolute
# 43                          367215
# 9                           233420
# 2                           120693
# 33                          106469
# 10                          106292
# 47                           91024
# 5                            67449
# 40                           64558
# 42                           57543
# 28                           52815
# 44                           52408
# 4                            50635
# 14                           36722
# 12                           36529
# 37                           35851
# 46                           34233
# 23                           33383
# 36                           16736
# 25                           15805
# 0                            15504
# 49                           15028
# 35                           12759
# 20                            9878
# 21                            9868
# 27                            8794
# 7                             8285
# 26                            8113
# 3                             8071
# 17                            6520
# 15                            6452
# 29                            6246
# 41                            5961
# 19                            5155
# 8                             4202
# 31                            4088
# 34                            3982
# 22                            2785
# 16                            1955
# 50                            1158
# 39                            1074
# 38                            1067
# 51                             340
# 45                             369
# 1                             3594
# 30                            3835
# 11                            4721
# 24                            4871
# 6                             6233
# 18                           10896
# 48                           12144
# 13                           51250
# 32                           76790

# %%
# Filter states with population difference > 50000
df_greater_50000 = df_population_difference_sorted[df_population_difference_sorted.population_difference_absolute > 50000]
df_greater_50000
# Out:
#             states  id  population  population_difference  \
# 43           Texas  48    28995881                 367215
# 9          Florida  12    21477737                 233420
# 2          Arizona   4     7278717                 120693
# 33  North Carolina  37    10488084                 106469
# 10         Georgia  13    10617423                 106292
# 47      Washington  53     7614893                  91024
# 5         Colorado   8     5758736                  67449
# 40  South Carolina  45     5148714                  64558
# 42       Tennessee  47     6829174                  57543
# 28          Nevada  32     3080156                  52815
# 44            Utah  49     3205958                  52408
# 4       California   6    39512223                  50635
# 13        Illinois  17    12671821                 -51250
# 32        New York  36    19453561                 -76790
#
#     population_difference_absolute
# 43                          367215
# 9                           233420
# 2                           120693
# 33                          106469
# 10                          106292
# 47                           91024
# 5                            67449
# 40                           64558
# 42                           57543
# 28                           52815
# 44                           52408
# 4                            50635
# 13                           51250
# 32                           76790

# %%
# % of States with population difference > 50000
int((len(df_greater_50000)/df_population_difference_sorted.states.nunique())*100)
# Out:
# 26

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Heatmap

# %%
import altair as alt

alt.themes.enable("dark")

heatmap = alt.Chart(df_reshaped).mark_rect().encode(
        y=alt.Y('year:O', axis=alt.Axis(title="Year", titleFontSize=16, titlePadding=15, titleFontWeight=900, labelAngle=0)),
        x=alt.X('states:O', axis=alt.Axis(title="States", titleFontSize=16, titlePadding=15, titleFontWeight=900)),
        color=alt.Color('max(population):Q',
                         legend=alt.Legend(title=" "),
                         scale=alt.Scale(scheme="blueorange")),
        stroke=alt.value('black'),
        strokeWidth=alt.value(0.25),
        #tooltip=[
        #    alt.Tooltip('year:O', title='Year'),
        #    alt.Tooltip('population:Q', title='Population')
        #]
    ).properties(width=900
    #).configure_legend(orient='bottom', titleFontSize=16, labelFontSize=14, titlePadding=0
    #).configure_axisX(labelFontSize=14)
    ).configure_axis(
    labelFontSize=12,
    titleFontSize=12
    )

heatmap
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Choropleth

# %%
# Choropleth via Altair
import altair as alt
from vega_datasets import data

alt.themes.enable("dark")

states = alt.topo_feature(data.us_10m.url, 'states')

alt.Chart(states).mark_geoshape().encode(
    color=alt.Color('population:Q', scale=alt.Scale(scheme='blues')),   # scale=color_scale
    stroke=alt.value('#154360')
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(df_selected_year, 'id', list(df_selected_year.columns))
).properties(
    width=500,
    height=300
).project(
    type='albersUsa'
)
# Out:
# alt.Chart(...)

# %%
# Choropleth via Plotly
import plotly.express as px

choropleth = px.choropleth(df_selected_year, locations='states_code', color='population', locationmode="USA-states",
                               color_continuous_scale='blues',
                               range_color=(0, max(df_selected_year.population)),
                               scope="usa",
                               labels={'population':'Population'}
                              )
choropleth.update_layout(
        template='plotly_dark',
        plot_bgcolor='rgba(0, 0, 0, 0)',
        paper_bgcolor='rgba(0, 0, 0, 0)',
        margin=dict(l=0, r=0, t=0, b=0),
        height=350
    )

choropleth
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3e25d7b2-e382-40f5-92b6-b0b9257f8c58" class="plotly-graph-div" style="height:350px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e25d7b2-e382-40f5-92b6-b0b9257f8c58")) {                    Plotly.newPlot(                        "3e25d7b2-e382-40f5-92b6-b0b9257f8c58",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"states_code=%{location}\u003cbr\u003ePopulation=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","DC","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY","PR"],"name":"","z":[4903185,731545,7278717,3017804,39512223,5758736,3565287,973764,705749,21477737,10617423,1415872,1787065,12671821,6732219,3155070,2913314,4467673,4648794,1344212,6045680,6892503,9986857,5639632,2976149,6137428,1068778,1934408,3080156,1359711,8882190,2096829,19453561,10488084,762062,11689100,3956971,4217737,12801989,1059361,5148714,884659,6829174,28995881,3205958,623989,8535519,7614893,1792147,5822434,578759,3193694],"type":"choropleth"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444 ...
